# %% [markdown]
# <h1> Analyzing and Forecasting Rainfall (Monthly Avg) using statistical methods and Machine Learning. </h1>
#
#
# The Excel file has 02 sheets (Avg and SE). Avg is the average value of the concerned parameter while SE has the standard error associated with the average value.
# The file has monthly time series data from Jan 1990 to Dec 2022. The parameter in column B is rainfall (consider as Y), while indices from column C to K affect rainfall over a region (consider as X). Details of parameters from columns C to K are:
#
# * RH_%: Relative humidity (in %)
# * Dew_Point_°C: Dew point temperature (in °C)
# * Cloud_Amount_%: Cloud cover fraction (in %)
# * Air_T_°C: Air temperature (in °C)
# * WS_m/s: Wind speed (in m/s)
# * SWR_W/m2: Shortwave radiation (in W/m2)
# * Soil_Mois_cum/cum: Soil moisture in the top 10 cm of soil (in cu.m/cu.m)
# * Air_Pres_Pa: Air pressure (in Pa)
# * ET_mm/month: Evapotranspiration (in mm/month)
#
#
# * <b>Training dataset: 01 Jan 1990 to 31 Dec 2013 </b>
# * <b>Validation dataset: 01 Jan 2014 to 31 Dec 2022   </b>
#
#
#
# We are exploring the possibilities of rainfall prediction using the SVM and random forest and other models.
# The preferred model performance indicators to use are
# * RMSE
# * MAE (mean absolute error), and
# * MAPE (mean absolute percentage error).

# %%
#Import necessary py libraries
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

#to ignore warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# J:\anaconda3\envs\tf\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

import itertools

# Preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# Boosting techniques
import lightgbm as lgb
import xgboost as xgb
from xgboost import plot_importance, plot_tree
import catboost as cat
print(f"\nLightGBM = {lgb.__version__}| XGBoost = {xgb.__version__}| CatBoost = {cat.__version__}\n\n");


from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
# Out:
# LightGBM = 4.5.0| XGBoost = 1.7.6| CatBoost = 1.2.3

# %%
#Prophet
from prophet import Prophet

# %%
#DeepLearning Framework
import tensorflow as tf
print("TF Version:", tf.__version__)
import keras
print("Keras Version:", keras.__version__)

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
# Out:
# TF Version: 2.10.1
# Keras Version: 2.10.0

# %%
#Capture CUDA details
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7124013566308617980
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5744099328
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8872612981690949163
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:26:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
#Function to Save all metrices to one table
# lst=('Method', 'rmse', 'mae', 'mape')
# eval_matrix = pd.DataFrame(columns =lst, dtype=np.dtype([('str', 'float', 'float','float')]))

# Create empty DataFrame to Save all metrices to one table
eval_matrix = pd.DataFrame({'Method': pd.Series(dtype='str'),
                   'rmse': pd.Series(dtype='float'),
                   'mae': pd.Series(dtype='float'),
                   'mape': pd.Series(dtype='float')})

def add_eval(em, method, rmse, mae, mape):
  
    df_temp = pd.DataFrame({'Method':[method], 'rmse':[rmse], 'mae':[mae], 'mape':[mape]})
    #print(df_temp)
    em = em.append(df_temp, ignore_index=True)
    #print(em)
    return em
    
#eval_matrix

# %%
# # Dependency for excel read (One time)
# !pip install openpyxl

# %%
# Check working directory/ set working directory/ set input folder path

path = "P:\IT\Rainfall-TS-Sep2024\Rainfall_Timeseries"
print("Current working directory is set as:", path)
file_path = path+'\\input'
print("Input files are under the folder:", file_path)

#List files under input folder
os.listdir(file_path)
# Out:
# Current working directory is set as: P:\IT\Rainfall-TS-Sep2024\Rainfall_Timeseries
# Input files are under the folder: P:\IT\Rainfall-TS-Sep2024\Rainfall_Timeseries\input
# ['Data_Rainfall_Prediction_USGCM.xlsx']

# %%
Avg = file_path+"\\Data_Rainfall_Prediction_USGCM.xlsx"


# Read the input files

df_Avg = pd.read_excel(file_path +"\\Data_Rainfall_Prediction_USGCM.xlsx", sheet_name=0)
df_SE = pd.read_excel(file_path +"\\Data_Rainfall_Prediction_USGCM.xlsx", sheet_name=1)

# %% [markdown]
# <h2> Descriptive Analytics on Dataset </h2>

# %%
df_Avg
# Out:
#     Month-year     Rain_mm       RH_%  Dew_Point_°C  Cloud_Amount_%  \
# 0   1990-01-01    9.014030  29.964444     -1.340000       28.943333
# 1   1990-02-01   31.475803  42.185556      4.015556       54.024444
# 2   1990-03-01   17.078917  30.737778      3.087778       44.677778
# 3   1990-04-01    2.704660  17.756667      1.768889       36.974444
# 4   1990-05-01   16.200781  26.618889     12.231111       70.660000
# ..         ...         ...        ...           ...             ...
# 391 2022-08-01  188.385804  77.000000     24.718889       81.926667
# 392 2022-09-01  253.565665  78.410000     24.028889       60.655556
# 393 2022-10-01  127.415645  76.618889     19.396667       30.790000
# 394 2022-11-01    0.031965  69.993333     12.811111       16.972222
# 395 2022-12-01    2.372392  60.513333      6.810000       23.676667
#
#       Air_T_°C    WS_m/s    SWR_W/m2  Soil_Mois_cum/cum   Air_Pres_Pa  \
# 0    19.730960  5.889429  157.799111           0.190516  99850.118606
# ...

# %%
df_SE
# Out:
#     Month-year   Rain_mm      RH_%  Dew_Point_°C  Cloud_Amount_%  Air_T_°C  \
# 0   1990-01-01  0.079583  0.644994      0.214437        2.472732  0.061176
# 1   1990-02-01  0.398202  1.197770      0.098645        0.968860  0.076334
# 2   1990-03-01  0.145088  2.034543      0.553396        0.936011  0.084061
# 3   1990-04-01  0.107626  0.820369      0.276428        2.190209  0.064854
# 4   1990-05-01  0.317898  0.337711      0.151982        2.110934  0.024254
# ..         ...       ...       ...           ...             ...       ...
# 391 2022-08-01  1.540608  2.176294      0.260520        0.954321  0.032938
# 392 2022-09-01  1.721940  2.057870      0.272690        2.969574  0.033339
# 393 2022-10-01  0.838470  0.530787      0.206868        0.935739  0.015943
# 394 2022-11-01  0.012082  0.961290      0.193358        2.510118  0.018776
# 395 2022-12-01  0.095602  1.457933      0.433490        1.929064  0.032802
#
#        WS_m/s  SWR_W/m2  Soil_Mois_cum/cum  Unnamed: 9  ET_mm/month
# ...

# %%
df_Avg.describe()
# Out:
#           Rain_mm        RH_%  Dew_Point_°C  Cloud_Amount_%    Air_T_°C  \
# count  396.000000  396.000000    396.000000      396.000000  396.000000
# mean    75.453002   47.464167     11.262910       45.307045   26.709498
# std    104.863389   21.234400      9.378826       22.013287    6.217932
# min      0.000000    8.403333     -6.104444        5.965556   14.004320
# 25%      7.205603   29.853611      3.116944       28.865278   21.211767
# 50%     17.302752   44.607778      8.945000       41.230556   27.614273
# 75%    128.241655   65.521389     21.187222       61.312778   31.526174
# max    465.058800   87.320000     25.921111       92.045556   37.843787
#
#            WS_m/s    SWR_W/m2  Soil_Mois_cum/cum    Air_Pres_Pa  ET_mm/month
# count  396.000000  396.000000         396.000000     396.000000   396.000000
# mean     4.445463  186.307274           0.241711   99107.976901    64.687739
# std      0.795651   37.917461           0.075716     662.403859    46.333728
# ...

# %%
df_Avg.corr()
# Out:
#                     Rain_mm      RH_%  Dew_Point_°C  Cloud_Amount_%  Air_T_°C  \
# Rain_mm            1.000000  0.727830      0.817442        0.799042  0.300009
# RH_%               0.727830  1.000000      0.799814        0.424880 -0.142170
# Dew_Point_°C       0.817442  0.799814      1.000000        0.688347  0.459805
# Cloud_Amount_%     0.799042  0.424880      0.688347        1.000000  0.501925
# Air_T_°C           0.300009 -0.142170      0.459805        0.501925  1.000000
# WS_m/s             0.072354 -0.394333     -0.087703        0.336223  0.461461
# SWR_W/m2          -0.029835 -0.451631      0.092514        0.233488  0.861652
# Soil_Mois_cum/cum  0.818991  0.934725      0.849203        0.526675  0.067096
# Air_Pres_Pa       -0.631598 -0.197367     -0.705230       -0.754324 -0.893916
# ET_mm/month        0.767379  0.879845      0.761668        0.443870 -0.016991
#
#                      WS_m/s  SWR_W/m2  Soil_Mois_cum/cum  Air_Pres_Pa  \
# ...

# %%
df_Avg.shape
# Out:
# (396, 11)

# %%
df_Avg.isna().sum()
# Out:
# Month-year           0
# Rain_mm              0
# RH_%                 0
# Dew_Point_°C         0
# Cloud_Amount_%       0
# Air_T_°C             0
# WS_m/s               0
# SWR_W/m2             0
# Soil_Mois_cum/cum    0
# Air_Pres_Pa          0
# ET_mm/month          0
# dtype: int64

# %%
df_Avg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Month-year         396 non-null    datetime64[ns]
#  1   Rain_mm            396 non-null    float64
#  2   RH_%               396 non-null    float64
#  3   Dew_Point_°C       396 non-null    float64
#  4   Cloud_Amount_%     396 non-null    float64
#  5   Air_T_°C           396 non-null    float64
#  6   WS_m/s             396 non-null    float64
#  7   SWR_W/m2           396 non-null    float64
#  8   Soil_Mois_cum/cum  396 non-null    float64
#  9   Air_Pres_Pa        396 non-null    float64
#  10  ET_mm/month        396 non-null    float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 34.2 KB

# %% [markdown]
# <h2> Key observations on rainfall data from Descriptive analysis </h2>
#
# * Rows, cols = (396, 11)
# * DateTime is index column
# * Rest are float
# * 2 Parameters with negative corr wrt rainfall (rest are positive)
#     1. SWR_W/m2: Shortwave radiation (in W/m2)
#     2. Air_Pres_Pa: Air pressure (in Pa)
#
# * No NULL value
#
# <I> Clean data sample!
#     Good data collection and cleaning job!!
#     :) Nothing to be done here.</I>

# %% [markdown]
# <h2> 28/09/2024: Some recommended changes to dataset based on further analysis </h2>
#
# we should select the following parameters for the prediction model
#
# * Dew_Point_°C
# * Cloud_Amount_%
# * Soil_Mois_cum/cum
# * ET_mm/month
# * Air_Pres_Pa
# * SWR_W/m2
#
# Further, we may translate the Dew_Point_°C to Kelvin (by adding 273.15 to column D) for positive values of the respective parameter.

# %%
data_v2 = df_Avg.copy() #Create a copy before transformations, we can always fallback to this if something goes off
# spliting date
data_v2['year'] = data_v2['Month-year'].dt.year 
data_v2['month'] = data_v2['Month-year'].dt.month
data_v2.rename(columns={'Month-year':'date'}, inplace=True)
data_v2['Dew_Point_°K'] = data_v2['Dew_Point_°C'] + 273.15
#data_v2.head()
#Other Transformations 
drop_list = ['RH_%', 'Dew_Point_°C','Air_T_°C','WS_m/s']
data_v2 = data_v2.drop(columns=drop_list)

data_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               396 non-null    datetime64[ns]
#  1   Rain_mm            396 non-null    float64
#  2   Cloud_Amount_%     396 non-null    float64
#  3   SWR_W/m2           396 non-null    float64
#  4   Soil_Mois_cum/cum  396 non-null    float64
#  5   Air_Pres_Pa        396 non-null    float64
#  6   ET_mm/month        396 non-null    float64
#  7   year               396 non-null    int64
#  8   month              396 non-null    int64
#  9   Dew_Point_°K       396 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(2)
# memory usage: 31.1 KB

# %% [markdown]
# <h2> Let's dig deep to analyse timeseries properties </h2>

# %%
#------------------ Will use data_v2 now --------------------------------

# #Some data prep
# data= df_Avg.copy() #Create a copy before transformations, we can always fallback to this if something goes off
# #data
# # spliting date
# data['year'] = data['Month-year'].dt.year 
# data['month'] = data['Month-year'].dt.month
# data.rename(columns={'Month-year':'date'}, inplace=True)
# data.info()

# %% [markdown]
# <h2>Plotting Line plot for Time Series data </h2>
#
#
# Please note that data is already re-sampled to Monthly average. Since, the volume column is of continuous data type, we will use line graph to visualize it. As it's 'Rain Data' we expect it to have seasonality.

# %%
# # If 'Date' is a column, but not the index, you can set it as the index
#data.set_index('date', inplace=True)
data_v2.set_index('date', inplace=True)

# %%
#See Monthly Patterns
sns.boxplot(x="month", y="Rain_mm", data=data_v2)
#Yes, monsoon!
# Out:
# <AxesSubplot:xlabel='month', ylabel='Rain_mm'>

# %%
# Assuming df is your DataFrame
sns.set(style="whitegrid") # Setting the style to whitegrid for a clean background

plt.figure(figsize=(12, 6)) # Setting the figure size
sns.lineplot(data=data_v2, x='date', y='Rain_mm', label='Rain_mm', color='blue')

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Rain_mm')
plt.title('Avg Monthly Rainfall(mm) Over Time')

plt.show()

# %%
#12-M Moving Average

plt.figure(figsize=(20,5))
twelve_months_moving_average = data_v2['Rain_mm'].rolling(window=12).mean()
sns.lineplot(data=data_v2, x='date', y='Rain_mm', label='Rain_mm', color='blue')
plt.plot(twelve_months_moving_average, color='red', label='Rolling Mean')
plt.legend(loc='best')
plt.title('12 Months Moving Average')
# Out:
# Text(0.5, 1.0, '12 Months Moving Average')

# %% [markdown]
# <h2> Detecting Seasonality Using Auto Correlation </h2>
#
# We will detect Seasonality using the autocorrelation function (ACF) plot.
# Peaks at regular intervals in the ACF plot suggest the presence of seasonality.

# %%
# Plot the ACF
plt.figure(figsize=(18, 6))
plot_acf(data_v2['Rain_mm'], lags=12)  # As it is monthly data, a lag of 12 would represent an yearly cycle
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function (ACF) Plot')
plt.show()

# %% [markdown]
# We can see that we have <b> Seasonality </b> in our monthly data. (Data is also cyclic: Try lag in multiples of 12 to see visual evidence. It show resets evey 12 months.)

# %% [markdown]
# <h2>Detecting Stationarity</h2>
#
# We will perform the ADF test to formally test for stationarity.
#
# The test is based on:
#
# * Null hypothesis that a unit root is present in the time series, indicating that the series is non-stationary.
# * The alternative hypothesis is that the series is stationary after differencing (i.e., it has no unit root).
# * The ADF test employs an augmented regression model that includes lagged differences of the series to determine the presence of a unit root.

# %%
# Assuming df is your DataFrame
result = adfuller(data_v2['Rain_mm'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: -4.262360091385562
# p-value: 0.0005158194038951083
# Critical Values: {'1%': -3.4475850438570115, '5%': -2.869135963767125, '10%': -2.5708164748773332}

# %%
### data (v1) results --------------------------------------------------same as data_v2 results
# ADF Statistic: -4.2623600913855775
# p-value: 0.0005158194038950781
# Critical Values: {'1%': -3.4475850438570115, '5%': -2.869135963767125, '10%': -2.5708164748773332}

# %% [markdown]
# Based on the
# * ADF Stat < all Critical Values.
# * p-value**: 0.0005158194038950781
# So, <b>we accept the Alternate hypothesis and conclude that the data appear to be stationary </b> according to the <i>Augmented Dickey-Fuller test.</i>
#
# * This suggests that differencing or other transformations may NOT be needed to achieve stationarity before applying certain time series models
#
# * D-F Test we want p-value** < 0.05 to reject its null hypothesis. Based on the test which been done before, we can comfortably say that our training data is stationary.

# %% [markdown]
# <h2> Decompose TS</h2>

# %%
# Decompose the time series using the seasonal_decompose function
decomposition = seasonal_decompose(data_v2['Rain_mm'], model='additive', period=12)

# %%
# Plot the decomposed components
fig, axes = plt.subplots(4, 1, figsize=(10, 8))
decomposition.observed.plot(ax=axes[0], title='Observed')
decomposition.trend.plot(ax=axes[1], title='Trend')
decomposition.seasonal.plot(ax=axes[2], title='Seasonal')
decomposition.resid.plot(ax=axes[3], title='Residual')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> Let's make some Models </h2>

# %%
#Prepare Target
#Y = data['Rain_mm']
Y = data_v2['Rain_mm']
#Y

#Prepare features

features = list(data_v2.select_dtypes(include = np.number).columns)
#features.remove('Rain_mm')
# Features to remove
to_remove = ['Rain_mm','day','year', 'month']

# Removing non-feature cols from list
features = [f for f in features if f not in to_remove]

#print(features)
#Features to exog (For Sarimax)
exog = data_v2[features]

# %% [markdown]
# <h3>1. SARIMAX Model </h3>
# SARIMA extends ARIMA's capabilities to handle seasonal patterns.
# SARIMAX further enhances the model's predictive accuracy by incorporating exogenous variables.
# X= Multivariate

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Parameter definition for best model selection, we will use AIC as model metric - lesser the better

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, d and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

#Initiate AIC Score

AIC_scores_list = []

#pdq
#seasonal_pdq

# %%
#Run all the combinations to find the best fit
best_aic = np.inf
best_pdq = None
best_seasonal_pdq = None
temp_model = None

for param in pdq:
    for param_seasonal in seasonal_pdq:
        temp_model = SARIMAX(Y,exog=exog,order = param,seasonal_order = param_seasonal, enforce_stationarity=True, enforce_invertibility=True)
        results = temp_model.fit()
        l = []
        l.append(param[0])
        l.append(param[1])
        l.append(param[2])
        l.append(param_seasonal[0])
        l.append(param_seasonal[1])
        l.append(param_seasonal[2])
        l.append(param_seasonal[3])
        l.append(results.aic)
        AIC_scores_list.append(l)
        if results.aic < best_aic:
            best_aic = results.aic
            best_pdq = param
            best_seasonal_pdq = param_seasonal
      

print("Best SARIMAX{}x{}12 model - AIC:{}".format(best_pdq, best_seasonal_pdq, best_aic))
# Out:
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
#Data(v1) Best model per last RUN: Best SARIMAX(1, 1, 1)x(0, 1, 1, 12)12 model - AIC:3689.0420654543386
#Data(v2) Best model per last RUN: Best SARIMAX(1, 1, 1)x(0, 1, 1, 12)12 model - AIC:3695.3685873168743


AIC_scores = pd.DataFrame.from_records(AIC_scores_list)
AIC_scores.columns=['p', 'd', 'q', 'P', 'D', 'Q', 's', 'AIC']
AIC_scores.iloc[AIC_scores['AIC'].argmin()]
# Out:
# p         1.000000
# d         1.000000
# q         1.000000
# P         0.000000
# D         1.000000
# Q         1.000000
# s        12.000000
# AIC    3695.298984
# Name: 59, dtype: float64

# %%
#See more AIC Details
AIC_scores.head(10)
# Out:
#    p  d  q  P  D  Q   s          AIC
# 0  0  0  0  0  0  0  12  6001.250978
# 1  0  0  0  0  0  1  12  4012.553658
# 2  0  0  0  0  1  0  12  3871.665807
# 3  0  0  0  0  1  1  12  3709.984402
# 4  0  0  0  1  0  0  12  4005.182815
# 5  0  0  0  1  0  1  12  3995.792261
# 6  0  0  0  1  1  0  12  3777.534034
# 7  0  0  0  1  1  1  12  3711.805557
# 8  0  0  1  0  0  0  12  4023.526334
# 9  0  0  1  0  0  1  12  4011.075254

# %%
plt.figure(figsize=(20,5))
plt.plot(AIC_scores.AIC, color='blue')
plt.plot(27, AIC_scores.AIC[27], 'r*')

# %%
print(best_pdq)
print(best_seasonal_pdq)
# Out:
# (1, 1, 1)
# (0, 1, 1, 12)

# %% [markdown]
# <h3>AIC Analysis: Best Model Selection</h3>
# After fitting the data with different combination of models, we got the best parameters as following:
#
#     * p = 1, d = 1, q = 1
#     * P = 0, D = 1, Q = 1
#     * s = 12

# %% [markdown]
# <h3> Run Best Model </h3>

# %%
best_model = SARIMAX(Y,
                     exog=exog,
                     order = best_pdq,
                     seasonal_order = best_seasonal_pdq, 
                     enforce_stationarity=True, 
                     enforce_invertibility=True)
results = best_model.fit()
# Out:
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# J:\anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#See results
print(results.summary().tables[0])
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                            Rain_mm   No. Observations:                  396
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood               -1837.649
# Date:                            Sat, 05 Oct 2024   AIC                           3695.299
# Time:                                    20:26:27   BIC                           3734.779
# Sample:                                01-01-1990   HQIC                          3710.960
#                                      - 12-01-2022
# Covariance Type:                              opg
# ...

# %%
#data (V1) result
# SARIMAX Results                                      
# ==========================================================================================
# Dep. Variable:                            Rain_mm   No. Observations:                  396
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood               -1831.481
# Date:                            Sat, 28 Sep 2024   AIC                           3688.961
# Time:                                    15:13:46   BIC                           3740.285
# Sample:                                01-01-1990   HQIC                          3709.321
#                                      - 12-01-2022                                         
# Covariance Type:                              opg                                         
# ==========================================================================================

#data (V2) result
# SARIMAX Results                                      
# ==========================================================================================
# Dep. Variable:                            Rain_mm   No. Observations:                  396
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood               -1837.684
# Date:                            Sat, 28 Sep 2024   AIC                           3695.369
# Time:                                    15:55:19   BIC                           3734.849
# Sample:                                01-01-1990   HQIC                          3711.030
#                                      - 12-01-2022                                         
# Covariance Type:                              opg                                         
# ==========================================================================================

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('2014-01-01'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()

# %%
y_pred = pred_dynamic.predicted_mean

# %%
#SARIMAX can predict some neg values, as we are talking about rain - we will replace neg values with Zero
y_pred[y_pred<0]=0
#y_pred

# %%
y_test = Y['2014':]

# %%
import math
rmse = math.sqrt(((y_pred - y_test) ** 2).mean())
print('The Mean Squared Error of our predictions is {}'.format(round(rmse, 4)))

# data(v1) RMSE: The Mean Squared Error of our predictions is 30.3417
# data(v2) RMSE: The Mean Squared Error of our predictions is 30.2905
# Non-negative treatment on data(v2) RMSE:The Mean Squared Error of our predictions is 29.3575
# Out:
# The Mean Squared Error of our predictions is 29.3199

# %%
# rmse = math.sqrt(mean_squared_error(y_test, y_pred))
# rmse

# %%
# Plot the actual values.
axis_plt = Y['1985':].plot(label='Train data', figsize=(10, 6))

# Plot the predicted values.
pred_dynamic.predicted_mean.plot(ax=axis_plt, label='Predictions')

# Plot confidence values and fill it with some colour.
# axis_plt.fill_between(pred_dynamic_ci.index, pred_dynamic_ci.iloc[:, 0], pred_dynamic_ci.iloc[:, 1], color='k', alpha=0.1)
axis_plt.fill_betweenx(axis_plt.get_ylim(), pd.to_datetime('2014'), Y.index[-1], alpha=0.1, zorder=-1)

# Set labels.
axis_plt.set_xlabel('Years')
axis_plt.set_ylabel('Monthly Avg Rainfall in mm')

# Put legend on the plot at the best place it fits.
plt.legend(loc='best')

# %%
# os.getcwd()

# %%
# #Store predictions to test set and export in csv
sarimax_pred = data_v2['2014':]
sarimax_pred['Rainfall_Prediction']=y_pred
# sarimax_pred.to_csv("Output\sarimax_pred_non_neg_v2.csv")
# del sarimax_pred

method = "SARIMAX"
rmse = mean_squared_error(y_true=sarimax_pred['Rain_mm'],y_pred=sarimax_pred['Rainfall_Prediction'])
mae = mean_absolute_error(y_true=sarimax_pred['Rain_mm'],y_pred=sarimax_pred['Rainfall_Prediction'])
mape = mean_absolute_percentage_error(y_true=sarimax_pred['Rain_mm'],y_pred=sarimax_pred['Rainfall_Prediction'])
eval_matrix = add_eval(eval_matrix,method, rmse, mae, mape)
print('EVAL_Matrix:\n', display(eval_matrix))
# Out:
#     Method        rmse        mae      mape
# 0  SARIMAX  859.654359  20.115472  16.07131
# EVAL_Matrix:
#  None

# %%
print('RMSE: ', rmse)
print('MAE: ', mae)
print('MAPE: ', mape)
display(eval_matrix)
# Out:
# RMSE:  859.6543590853457
# MAE:  20.115472015391834
# MAPE:  16.071310037951577
#     Method        rmse        mae      mape
# 0  SARIMAX  859.654359  20.115472  16.07131

# %%
SARIMAX_Nonzero = sarimax_pred[['Rain_mm','Rainfall_Prediction']]
print(SARIMAX_Nonzero.info())

index_names = SARIMAX_Nonzero[(SARIMAX_Nonzero['Rainfall_Prediction'] == 0)].index 
  
# drop these given row 
# indexes from dataFrame 
SARIMAX_Nonzero.drop(index_names, inplace = True)
SARIMAX_Nonzero.info()

#we now only have 88 records vs 108

method = "SARIMAX_NonZero"
rmse = mean_squared_error(y_true=SARIMAX_Nonzero['Rain_mm'],y_pred=SARIMAX_Nonzero['Rainfall_Prediction'])
mae = mean_absolute_error(y_true=SARIMAX_Nonzero['Rain_mm'],y_pred=SARIMAX_Nonzero['Rainfall_Prediction'])
mape = mean_absolute_percentage_error(y_true=SARIMAX_Nonzero['Rain_mm'],y_pred=SARIMAX_Nonzero['Rainfall_Prediction'])
eval_matrix = add_eval(eval_matrix,method, rmse, mae, mape)
print('EVAL_Matrix:\n', display(eval_matrix))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 108 entries, 2014-01-01 to 2022-12-01
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rain_mm              108 non-null    float64
#  1   Rainfall_Prediction  108 non-null    float64
# dtypes: float64(2)
# memory usage: 2.5 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88 entries, 2014-01-01 to 2022-11-01
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rain_mm              88 non-null     float64
#  1   Rainfall_Prediction  88 non-null     float64
# dtypes: float64(2)
# memory usage: 2.1 KB
#             Method         rmse        mae       mape
# 0          SARIMAX   859.654359  20.115472  16.071310
# 1  SARIMAX_NonZero  1023.372751  22.578954  19.496608
# EVAL_Matrix:
#  None

# %% [markdown]
# Try XGBOOST

# %%
#Split Test train
train = data_v2[:'2014']
test = data_v2['2014':]

#Training dataset
y_train = train["Rain_mm"]
X_train = train.drop("Rain_mm", axis=1)

#Testing dataset
y_test = test["Rain_mm"]
X_test = test.drop("Rain_mm", axis=1)

# %%
#Create XGB

reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False) # Change verbose to True if you want to see it train
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
#Feature Importance
_ = plot_importance(reg, height=0.9)

# %%
#Run XGB on test set
y_pred = reg.predict(X_test)
#y_pred

# %%
#Saving Predicted values to Pred df for ease of calculations/ visualization
pred = pd.DataFrame(index=y_test.index)
pred = pred.assign(Rain_mm=(y_pred))
#pred

# %%
# Plot the actual values.
axis_plt = y_test.plot(label='Train data', figsize=(10, 6))

# Plot the predicted values.
pred.plot(ax=axis_plt, label='Predictions')

# Plot confidence values and fill it with some colour.
# axis_plt.fill_between(pred_dynamic_ci.index, pred_dynamic_ci.iloc[:, 0], pred_dynamic_ci.iloc[:, 1], color='k', alpha=0.1)
axis_plt.fill_betweenx(axis_plt.get_ylim(), pd.to_datetime('2014'), Y.index[-1], alpha=0.1, zorder=-1)

# Set labels.
axis_plt.set_xlabel('Years')
axis_plt.set_ylabel('Monthly Avg Rainfall in mm')

# Put legend on the plot at the best place it fits.
plt.legend(loc='best')

# %%
test['Rainfall_Prediction'] = reg.predict(X_test)

train['Rain_mm'].plot(style='k', figsize=(10,5), label = 'train')
test['Rain_mm'].plot(style='b', figsize=(10,5), label = 'test')
test['Rainfall_Prediction'].plot(style='r', figsize=(10,5), label = 'prediction')
plt.title('Mean monthly rainfall')
plt.legend()

# %%
method = "XGBOOST"
rmse = mean_squared_error(y_true=test['Rain_mm'],y_pred=test['Rainfall_Prediction'])
mae = mean_absolute_error(y_true=test['Rain_mm'],y_pred=test['Rainfall_Prediction'])
mape = mean_absolute_percentage_error(y_true=test['Rain_mm'],y_pred=test['Rainfall_Prediction'])
             
eval_matrix = add_eval(eval_matrix,method, rmse, mae, mape)
print('EVAL_Matrix:\n', display(eval_matrix))
# Out:
#             Method         rmse        mae       mape
# 0          SARIMAX   859.654359  20.115472  16.071310
# 1  SARIMAX_NonZero  1023.372751  22.578954  19.496608
# 2          XGBOOST   655.850946  14.241800   3.176465
# EVAL_Matrix:
#  None

# %%
# print('RMSE: ', round(mean_squared_error(y_true=test['Rain_mm'],y_pred=test['Rainfall_Prediction']),3))
# print('MAE: ', round(mean_absolute_error(y_true=test['Rain_mm'],y_pred=test['Rainfall_Prediction']),3))
# print('MAPE: ', round(mean_absolute_percentage_error(y_true=test['Rain_mm'],y_pred=test['Rainfall_Prediction']),3))

# %%
# data v1 xgb statistics
# RMSE:  1028.738
# MAE:  17.679
# MAPE:  4.749
    
# data v2 xgb statistics
# RMSE:  824.157
# MAE:  16.217
# MAPE:  3.753

# %%
# test.to_csv("Output\\xgb_test_v2.csv")

# %% [markdown]
# <h2>Let's Move to LSTM</h2>

# %%
#Prepare data

lstm_df = data_v2.copy()
lstm_df.drop(['year', 'month'], axis=1, inplace=True) 
#lstm_df


#Perform scaling for model building
scaler = StandardScaler()
scaler = scaler.fit(lstm_df)
lstm_df_scaled = scaler.transform(lstm_df)
#lstm_df_scaled

# %%
#LSTM needs some data reshaping
trainX=[]
trainY=[]

n_future = 1   # Number of Months we want to look into the future based on the past days.
n_past = 24  # Number of past Months we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)

for i in range(n_past, len(lstm_df_scaled) - n_future +1):
    trainX.append(lstm_df_scaled[i - n_past:i, 0:lstm_df_scaled.shape[1]])
    trainY.append(lstm_df_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))
# Out:
# trainX shape == (372, 24, 7).
# trainY shape == (372, 1).

# %%
# define the Autoencoder model

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 24, 64)            18432
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 30,881
# Trainable params: 30,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss",
                                        mode="min",
                                        patience=5,
                                        restore_best_weights=True)

# %%
# fit the model
history = model.fit(trainX, trainY, epochs=50, batch_size=10, validation_split=0.3, verbose=1, callbacks=[earlystopping])

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
# Out:
# Epoch 1/50
# 26/26 [==============================] - 8s 79ms/step - loss: 0.9048 - val_loss: 0.9475
# Epoch 2/50
# 26/26 [==============================] - 2s 63ms/step - loss: 0.7151 - val_loss: 0.7377
# Epoch 3/50
# 26/26 [==============================] - 2s 65ms/step - loss: 0.5287 - val_loss: 0.4315
# Epoch 4/50
# 26/26 [==============================] - 2s 64ms/step - loss: 0.4041 - val_loss: 0.3393
# Epoch 5/50
# 26/26 [==============================] - 2s 64ms/step - loss: 0.3355 - val_loss: 0.3519
# Epoch 6/50
# 26/26 [==============================] - 2s 64ms/step - loss: 0.3298 - val_loss: 0.2799
# Epoch 7/50
# 26/26 [==============================] - 2s 63ms/step - loss: 0.3056 - val_loss: 0.2497
# Epoch 8/50
# 26/26 [==============================] - 2s 65ms/step - loss: 0.2677 - val_loss: 0.2412
# Epoch 9/50
# 26/26 [==============================] - 2s 62ms/step - loss: 0.2209 - val_loss: 0.3496
# Epoch 10/50
# ...

# %%
n_days_for_prediction=108  #let us predict past 108 days (2014 onwards in our dataset)

# %%
#Make prediction
prediction = model.predict(trainX[-n_days_for_prediction:]) #shape = (n, 1) where n is the n_days_for_prediction
# Out:
# 4/4 [==============================] - 0s 16ms/step

# %%
#Perform inverse transformation to rescale back to original range
#Since we used 5 variables for transform, the inverse expects same dimensions
#Therefore, let us copy our values 5 times and discard them after inverse transform
prediction_copies = np.repeat(prediction, lstm_df_scaled.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
y_pred_future
# Out:
# array([ 17.171309 ,  19.109892 ,  19.045488 ,  20.3035   ,  32.831326 ,
#         94.35183  , 215.9348   , 296.23383  , 211.76302  ,  85.62618  ,
#         28.8856   ,  24.71058  ,  24.226877 ,  22.036703 ,  16.480467 ,
#         18.644293 ,  42.654083 ,  97.355995 , 200.80562  , 262.9154   ,
#        196.78545  ,  77.49396  ,  34.753864 ,  30.562616 ,  25.969519 ,
#         18.77659  ,   8.959121 ,  11.810786 ,  46.392685 , 140.47765  ,
#        241.19241  , 288.674    , 180.74045  ,  40.096115 ,   7.2528143,
#         13.943282 ,  18.468203 ,  17.559381 ,  13.173026 ,  13.222156 ,
#         40.173656 , 134.1542   , 281.99924  , 328.48944  , 198.3094   ,
#         30.150347 ,   1.7036276,  11.820003 ,  16.613901 ,  14.497493 ,
#         10.815963 ,   8.388724 ,  41.164364 , 128.00322  , 271.7075   ,
#        330.2144   , 235.9067   ,  35.708797 ,  -4.23578  ,   8.896766 ,
#         14.634364 ,  14.0714445,  13.340919 ,  11.609969 ,  31.270712 ,
# ...

# %%
lstm_test = lstm_df.tail(108)
#lstm_test
lstm_test['Rainfall_Prediction'] = y_pred_future

# %%
train['Rain_mm'].plot(style='k', figsize=(10,5), label = 'train')
lstm_test['Rain_mm'].plot(style='b', figsize=(10,5), label = 'test')
lstm_test['Rainfall_Prediction'].plot(style='r', figsize=(10,5), label = 'prediction')
plt.title('Mean monthly rainfall')
plt.legend()

# %%
# print('RMSE: ', round(mean_squared_error(y_true=lstm_test['Rain_mm'],y_pred=lstm_test['Rainfall_Prediction']),3))
# print('MAE: ', round(mean_absolute_error(y_true=lstm_test['Rain_mm'],y_pred=lstm_test['Rainfall_Prediction']),3))
# print('MAPE: ', round(mean_absolute_percentage_error(y_true=lstm_test['Rain_mm'],y_pred=lstm_test['Rainfall_Prediction']),3))

# %%
# LSTM first run metrices
# RMSE:  1911.446
# MAE:  27.89
# MAPE:  9.089

# %%
method = "LSTM_RNN"
rmse = mean_squared_error(y_true=lstm_test['Rain_mm'],y_pred=lstm_test['Rainfall_Prediction'])
mae = mean_absolute_error(y_true=lstm_test['Rain_mm'],y_pred=lstm_test['Rainfall_Prediction'])
mape = mean_absolute_percentage_error(y_true=lstm_test['Rain_mm'],y_pred=lstm_test['Rainfall_Prediction'])
eval_matrix = add_eval(eval_matrix,method, rmse, mae, mape)
print('EVAL_Matrix:\n', display(eval_matrix))
# Out:
#             Method         rmse        mae       mape
# 0          SARIMAX   859.654359  20.115472  16.071310
# 1  SARIMAX_NonZero  1023.372751  22.578954  19.496608
# 2          XGBOOST   655.850946  14.241800   3.176465
# 3         LSTM_RNN  2180.999649  31.974956  14.920415
# EVAL_Matrix:
#  None

# %%
#Try Prophet

# %%
#Split Test train
prof_train = data_v2[:'2014']
prof_test = data_v2['2014':]

# %%
prof_train.rename(columns={'Rain_mm':'y'}, inplace=True)
prof_train['ds'] = prof_train.index
prof_train.drop(['year', 'month'], axis=1, inplace=True)

# %%
prof_test.rename(columns={'Rain_mm':'y'}, inplace=True)
prof_test['ds'] = prof_test.index
prof_test.drop(['year', 'month'], axis=1, inplace=True)

# %%
model=Prophet()
model.add_regressor('Cloud_Amount_%', standardize=False)
model.add_regressor('SWR_W/m2', standardize=False)
model.add_regressor('Soil_Mois_cum/cum', standardize=False)
model.add_regressor('Air_Pres_Pa', standardize=False)
model.add_regressor('ET_mm/month', standardize=False)
model.add_regressor('Dew_Point_°K', standardize=False)
model.fit(prof_train)
# Out:
# 20:27:15 - cmdstanpy - INFO - Chain [1] start processing
# 20:27:15 - cmdstanpy - INFO - Chain [1] done processing
# 20:27:15 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 20:27:15 - cmdstanpy - INFO - Chain [1] start processing
# 20:27:16 - cmdstanpy - INFO - Chain [1] done processing

# %%
model.params
# Out:
# OrderedDict([('lp__', array([[714.48]])),
#              ('k', array([[-0.0778148]])),
#              ('m', array([[5.82115]])),
#              ('delta',
#               array([[ 1.76021e-10,  6.80860e-11, -1.07326e-09, -2.26548e-06,
#                       -1.58530e-04, -1.84658e-04, -5.89425e-05, -9.04127e-06,
#                       -1.10269e-09, -1.21327e-11,  4.21418e-11, -6.66711e-11,
#                       -4.80125e-11,  8.36371e-11,  7.39915e-11,  5.72861e-05,
#                        3.81193e-04,  5.24218e-02,  1.02386e-04,  4.28085e-04,
#                        1.99977e-04,  2.42480e-09,  3.63467e-06,  6.87019e-11,
#                        6.50636e-11]])),
#              ('sigma_obs', array([[0.0557154]])),
#              ('beta',
#               array([[ 1.80947e-01, -3.10588e-01, -3.32716e-02, -1.03365e-02,
#                        2.99995e-03,  2.93853e-02,  9.99240e-03, -9.96107e-02,
#                        7.83906e-02, -1.94499e-02, -1.07695e-01, -6.32616e-03,
# ...

# %%
prof_pred = model.predict(prof_test)

# %%
prof_pred = prof_pred[['ds','yhat']]
prof_pred.head()
# Out:
#           ds       yhat
# 0 2014-01-01  41.837574
# 1 2014-02-01  56.520307
# 2 2014-03-01  63.025762
# 3 2014-04-01  -3.614445
# 4 2014-05-01 -17.152833

# %%
prof_test['Rainfall_Prediction'] = prof_pred['yhat'].to_numpy()
prof_test['Rainfall_Prediction'] = prof_test['Rainfall_Prediction'].apply(lambda x: max(x, 0))
prof_test.rename(columns={'y':'Rain_mm'}, inplace=True)

# %%
method = "Prophet"
rmse = mean_squared_error(y_true=prof_test['Rain_mm'],y_pred=prof_test['Rainfall_Prediction'])
mae = mean_absolute_error(y_true=prof_test['Rain_mm'],y_pred=prof_test['Rainfall_Prediction'])
mape = mean_absolute_percentage_error(y_true=prof_test['Rain_mm'],y_pred=prof_test['Rainfall_Prediction'])
eval_matrix = add_eval(eval_matrix,method, rmse, mae, mape)
print('EVAL_Matrix:\n', display(eval_matrix))
# Out:
#             Method         rmse        mae       mape
# 0          SARIMAX   859.654359  20.115472  16.071310
# 1  SARIMAX_NonZero  1023.372751  22.578954  19.496608
# 2          XGBOOST   655.850946  14.241800   3.176465
# 3         LSTM_RNN  2180.999649  31.974956  14.920415
# 4          Prophet   937.340760  20.723412  19.787863
# EVAL_Matrix:
#  None

# %%
#Try Catboost

# %%
# #Split Test train
# train = data_v2[:'2014']
# test = data_v2['2014':]

# #Training dataset
# y_train = train["Rain_mm"]
# X_train = train.drop("Rain_mm", axis=1)

# #Testing dataset
# y_test = test["Rain_mm"]
# X_test = test.drop("Rain_mm", axis=1)

# %%
# #X_train.columns
# cat_features = ['Cloud_Amount_%', 'SWR_W/m2', 'Soil_Mois_cum/cum', 'Air_Pres_Pa','ET_mm/month', 'year', 'month', 'Dew_Point_°K']

# for f in cat_features:
#     #print(f)
#     X_train[f] = X_train[f].astype(int) 
#     X_test[f] = X_test[f].astype(int) 
    
# X_train.info()

# %%
# #Build Cat model
# from sklearn.feature_selection import RFECV
# rate=['0.001', '0.01', '1']
# model = CatBoostRegressor(loss_function="RMSE",
#                            eval_metric="RMSE",
#                            task_type="GPU",
#                           n_estimators=5000, 
#                           cat_features=cat_features, 
#                           learning_rate=rate,
#                           max_bin=64,
#                           max_depth=3,
#                           random_seed=666)

# %%
# model.fit(X_train, y_train)

# %%
# from sklearn.model_selection import GridSearchCV

# model = CatBoostRegressor(loss_function="RMSE",
#                            eval_metric="RMSE",
#                            task_type="GPU",
#                            cat_features=cat_features,
#                           n_estimators=5000,
#                            max_bin=64,
#                            depth=3,
#                         random_seed=666)
# parameters = {
#               'learning_rate' : [0.01, 0.05, 0.1],
#               }

# grid = GridSearchCV(estimator=model, param_grid = parameters, cv = 3, n_jobs=-1, verbose=3)
# grid.fit(X_train, y_train)

# %%
# best_param = grid.best_params_
# best_param

# %%
# cat_pred=model.predict(X_test)

# %%
# cat_test = test.copy()
# cat_test['Rainfall_Prediction']=cat_pred
# cat_test

# %%
# method = "Catboost"
# rmse = mean_squared_error(y_true=cat_test['Rain_mm'],y_pred=cat_test['Rainfall_Prediction'])
# mae = mean_absolute_error(y_true=cat_test['Rain_mm'],y_pred=cat_test['Rainfall_Prediction'])
# mape = mean_absolute_percentage_error(y_true=cat_test['Rain_mm'],y_pred=cat_test['Rainfall_Prediction'])
# eval_matrix = add_eval(eval_matrix,method, rmse, mae, mape)
# print('EVAL_Matrix:\n', display(eval_matrix))

# %%
#Try Lightgbm

# %%
#Split Test train
train = data_v2[:'2014']
test = data_v2['2014':]

#Training dataset
y_train = train["Rain_mm"]
X_train = train.drop("Rain_mm", axis=1)

#Testing dataset
y_test = test["Rain_mm"]
X_test = test.drop("Rain_mm", axis=1)

#X_train.columns
lgb_features = ['Cloud_Amount_%', 'SWR_W/m2', 'Soil_Mois_cum/cum', 'Air_Pres_Pa','ET_mm/month', 'year', 'month', 'Dew_Point_°K']

# %%
lgb_params = {'objective': 'regression',
    'metric': 'l2',  # Regression metric (Mean Squared Error)
    'boosting_type': 'gbdt',
    'num_leaves': 10,
              'learning_rate': 0.02,
              'feature_fraction': 0.8,
              'max_depth': 5,
              'verbose': 0,
              'num_boost_round': 10000,
              'early_stopping_rounds': 200,
              'nthread': -1}

lgbtrain = lgb.Dataset(data=X_train, label=y_train, feature_name=lgb_features)

lgbval = lgb.Dataset(data=X_test, label=y_test, reference=lgbtrain, feature_name=lgb_features)

# %%
model = lgb.train(lgb_params, lgbtrain,
                  valid_sets=[lgbtrain, lgbval])
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
lgb_pred = model.predict(X_test, num_iteration=model.best_iteration)

# %%
lgb_test = test.copy()
lgb_test['Rainfall_Prediction']=lgb_pred
lgb_test
# Out:
#                Rain_mm  Cloud_Amount_%    SWR_W/m2  Soil_Mois_cum/cum  \
# date
# 2014-01-01   44.584237       52.227778  126.251478           0.244493
# 2014-02-01   28.469416       43.084444  159.306421           0.239013
# 2014-03-01   17.351543       31.563333  202.672592           0.227774
# 2014-04-01    5.333770       31.662222  236.895072           0.173646
# 2014-05-01   11.937630       40.908889  248.660299           0.159206
# ...                ...             ...         ...                ...
# 2022-08-01  188.385804       81.926667  196.557370           0.332387
# 2022-09-01  253.565665       60.655556  179.436452           0.349043
# 2022-10-01  127.415645       30.790000  167.869687           0.363000
# 2022-11-01    0.031965       16.972222  140.425897           0.272394
# 2022-12-01    2.372392       23.676667  129.404057           0.201455
#
#               Air_Pres_Pa  ET_mm/month  year  month  Dew_Point_°K  \
# date
# ...

# %%
method = "LightGBM"
rmse = mean_squared_error(y_true=lgb_test['Rain_mm'],y_pred=lgb_test['Rainfall_Prediction'])
mae = mean_absolute_error(y_true=lgb_test['Rain_mm'],y_pred=lgb_test['Rainfall_Prediction'])
mape = mean_absolute_percentage_error(y_true=lgb_test['Rain_mm'],y_pred=lgb_test['Rainfall_Prediction'])
eval_matrix = add_eval(eval_matrix,method, rmse, mae, mape)
print('EVAL_Matrix:\n', display(eval_matrix))
# Out:
#             Method         rmse        mae       mape
# 0          SARIMAX   859.654359  20.115472  16.071310
# 1  SARIMAX_NonZero  1023.372751  22.578954  19.496608
# 2          XGBOOST   655.850946  14.241800   3.176465
# 3         LSTM_RNN  2180.999649  31.974956  14.920415
# 4          Prophet   937.340760  20.723412  19.787863
# 5         LightGBM   852.896485  17.455196   4.349762
# EVAL_Matrix:
#  None
